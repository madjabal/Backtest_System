# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
def update_snp_store():
    data_path = 'data/'
    curr_raw = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    
    curr = curr_raw[0]
    hist = curr_raw[1]
    
    new_hist = pd.DataFrame(hist['Date'])
    new_hist['Added'] = hist['Added', 'Ticker']
    new_hist['Removed'] = hist['Removed', 'Ticker']
    
    curr.to_csv(data_path + 'snp_current.csv', index=False)
    new_hist.to_csv(data_path + 'snp_hist.csv', index=False)
    return None


def get_snp(date, date_format):
    data_path = 'data/'
    curr = pd.read_csv(data_path + 'snp_current.csv')
    hist = pd.read_csv(data_path + 'snp_hist.csv')
    
    start_date = datetime.strptime(date, date_format)
    
    snp_set = set(curr['Symbol'])
    
    for i in range(len(hist)):
        temp_date = datetime.strptime(hist.iloc[i]['Date'], date_format)
        if temp_date < start_date:
            break

        tb_removed = hist.iloc[i]['Added']
        tb_added = hist.iloc[i]['Removed']

        if tb_removed in snp_set:
            snp_set.remove(tb_removed)
        if not type(tb_added) == float:
            snp_set.add(tb_added)
    
    return list(snp_set)

# %%
date_format = '%B %d, %Y'
data_path = 'data/'

# %%
# update_snp_store()

# %%
get_snp('January 1, 2015', date_format)
# Out:
# ['FOXA',
#  'TJX',
#  'CFN',
#  'EL',
#  'ANDV',
#  'IR',
#  'RHI',
#  'GM',
#  'BBBY',
#  'GLW',
#  'CL',
#  'PNC',
#  'CCI',
#  'PDCO',
#  'LRCX',
#  'ALLE',
#  'GGP',
#  'HPQ',
#  'TSS',
#  'HSY',
#  'CCE',
#  'AN',
#  'ORLY',
#  'WELL',
#  'FE',
#  'SNI',
#  'SPLS',
#  'ABC',
#  'ADSK',
#  'ALL',
#  'ACN',
#  'PPG',
#  'TROW',
#  'TT',
#  'ADP',
#  'WYNN',
#  'MKC',
#  'EA',
#  'BLL',
#  'TGT',
#  'OKE',
#  'PXD',
#  'T',
#  'VRSN',
#  'PVH',
#  'TXN',
#  'BAC',
#  'MU',
#  'FLR',
#  'URBN',
#  'PGR',
#  'NI',
#  'CSX',
#  'PLD',
#  'MAT',
#  'IVZ',
#  'CMCSA',
#  'IPG',
#  'MNST',
#  'HAR',
#  'DNR',
#  'BIIB',
#  'SEE',
#  'BSX',
#  'NWSA',
#  'PCL',
#  'C',
#  'TEG',
#  'PWR',
#  'MO',
#  'AMAT',
#  'GOOG',
#  'DHI',
#  'ETN',
#  'AEE',
#  'FOSL',
#  'APH',
#  'CI',
#  'HAL',
#  'ADI',
#  'PPL',
#  'OXY',
#  'GOOGL',
#  'CMA',
#  'CAT',
#  'SRE',
#  'SPG',
#  'IFF',
#  'LB',
#  'HCBK',
#  'GIS',
#  'APA',
#  'VIAB',
#  'LLY',
#  'STX',
#  'LLTC',
#  'PRGO',
#  'DTV',
# ...

# %%
# UNFINISHED
# Get List of Company Name
# Input: None
# Output: CompanyList, a list of company names
import pandas as pd
from datetime import datetime
import numpy as np
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
#def get_company_name():
# Get current S&P table and set header column
sp500_current = list(data[0].loc[:,'Symbol'])
print(sp500_current)
# Out:
# ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BKR', 'BLL', 'BAC', 'BK', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'COTY', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'D
# ...

# %%
# UNFINISHED
import time
import datetime
changed_cmps = data[1].iloc[1:,[0,1,3]]
timetemp = data[1].iloc[1:,[0]]
timetemp = timetemp['Date']
startingtime = datetime.datetime(2015, 1, 1, 0, 0, 0)
sp500 = sp500_current
for i in range(0,len(changed_cmps)):
    timeArray = datetime.datetime.strptime(changed_cmps.iloc[i,0], "%B %d, %Y")
    if timeArray > startingtime:
        sp500.replace(changed_cmps.iloc[i,1],changed_cmps.iloc[i,2])

print(sp500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3d229cf9dfe2> in <module>
#      10     timeArray = datetime.datetime.strptime(changed_cmps.iloc[i,0], "%B %d, %Y")
#      11     if timeArray > startingtime:
# ---> 12         sp500.replace(changed_cmps.iloc[i,1],changed_cmps.iloc[i,2])
#      13
#      14 print(sp500)
#
# AttributeError: 'list' object has no attribute 'replace'
